# %% [markdown]
# # Dia 2 da semana de dados da Alura

# %% [markdown]
# ## Aula

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")
sns.set_palette("colorblind")

dados = pd.read_csv('dados_imoveis.csv')
dados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
dados["Valor"][0]
# Out:
# 'R$ 7.000.000'

# %%
dados["Valor"].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
dados["Valor"].str.split(expand=True)[0].unique()
# Out:
# array(['R$'], dtype=object)

# %%
dados["Valor"].str.split(expand=True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[["Moeda", "Valor_anuncio", "Tipo_anuncio"]
      ] = dados["Valor"].str.split(expand=True)
dados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
dados[dados["Tipo_anuncio"].isnull()]
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
dados_vendas = dados[dados["Tipo_anuncio"].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dados_vendas["Valor_anuncio"].str.replace(".", "").astype(float)
# Out:
# C:\Users\gabre\AppData\Local\Temp\ipykernel_19436\2927155442.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_vendas["Valor_anuncio"].str.replace(".", "").astype(float)
# 0       7000000.00
# 1       3700000.00
# 2        380000.00
# 3        685000.00
# 4        540000.00
#            ...
# 10002   1500000.00
# 10003    665000.00
# 10004   2300000.00
# 10005   1050000.00
# 10007    270000.00
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(
    ".", "").astype(float)

dados_vendas.to_csv('dados_vendas.csv', index=False)
dados_vendas
# Out:
# C:\Users\gabre\AppData\Local\Temp\ipykernel_19436\804495973.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(
# C:\Users\gabre\AppData\Local\Temp\ipykernel_19436\804495973.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rua                  6107 non-null   object
#  1   Bairro               9146 non-null   object
#  2   Cidade               9156 non-null   object
#  3   Metragem             9156 non-null   int64
#  4   Quartos              9156 non-null   int64
#  5   Banheiros            9156 non-null   int64
#  6   Vagas                9156 non-null   int64
#  7   Valor                9156 non-null   object
#  8   Moeda                9156 non-null   object
#  9   Valor_anuncio        9156 non-null   object
#  10  Tipo_anuncio         0 non-null      object
#  11  Valor_anuncio_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_vendas["Valor_anuncio_float"].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00

# %%
dados_vendas[["Rua", "Bairro", "Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
plt.figure(figsize=(10, 8))
ax = sns.histplot(data= dados_vendas, x = "Valor_anuncio_float", kde=True)
ax.set_title("Histograma do Valor dos Imóveis")
plt.xlim((-50, 10000000))
# Out:
# (-50.0, 10000000.0)

# %% [markdown]
# # Desafios
#
# 1 - Criar uma escala de valores em milhões.
#
# 2 - Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala).
#
# 3 - Preço do metro quadrado por bairro e plotar em um gráfico ideal.
#
# 4 - Explorar as bibliotecas de visualizações e colocar as suas conclusão.
#
# 5 - Pesquisar um visualização para analisar os quartis, mediana e outliers.

# %% [markdown]
# ### Desafio 1 & 2

# %%
dados_vendas.drop(["Valor", "Moeda", "Valor_anuncio",
                  "Cidade", "Tipo_anuncio"], axis=1, inplace=True)
dados_vendas
# Out:
# C:\Users\gabre\AppData\Local\Temp\ipykernel_19436\3119829912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas.drop(["Valor", "Moeda", "Valor_anuncio",
#                                   Rua              Bairro  Metragem  Quartos  \
# 0               Avenida Itacira, 255    Planalto Paulista      1000        4
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados       496        4
# 2                     Rua Alba Valdez     Jardim Reimberg       125        4
# 3                                 NaN      Jardim Morumbi       310        3
# 4            Rua Tobias Barreto, 195                Mooca       100        3
# ...                               ...                 ...       ...      ...
# 10002                   Avenida Odila   Planalto Paulista       267        3
# ...

# %%
dados_vendas.rename(columns={"Valor_anuncio_float": "Valor"}, inplace=True)
dados_vendas
# Out:
# C:\Users\gabre\AppData\Local\Temp\ipykernel_19436\4111630292.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas.rename(columns={"Valor_anuncio_float": "Valor"}, inplace=True)
#                                   Rua              Bairro  Metragem  Quartos  \
# 0               Avenida Itacira, 255    Planalto Paulista      1000        4
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados       496        4
# 2                     Rua Alba Valdez     Jardim Reimberg       125        4
# 3                                 NaN      Jardim Morumbi       310        3
# 4            Rua Tobias Barreto, 195                Mooca       100        3
# ...                               ...                 ...       ...      ...
# ...

# %%
dados_vendas['Valor_M'] = dados_vendas['Valor'].apply(lambda x: x/1000000)
dados_vendas
# Out:
# C:\Users\gabre\AppData\Local\Temp\ipykernel_19436\2978123624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas['Valor_M'] = dados_vendas['Valor'].apply(lambda x: x/1000000)
#                                   Rua              Bairro  Metragem  Quartos  \
# 0               Avenida Itacira, 255    Planalto Paulista      1000        4
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados       496        4
# 2                     Rua Alba Valdez     Jardim Reimberg       125        4
# 3                                 NaN      Jardim Morumbi       310        3
# 4            Rua Tobias Barreto, 195                Mooca       100        3
# ...                               ...                 ...       ...      ...
# ...

# %%
sns.set_context("poster", font_scale=1, rc={"grid.linewidth": 5, "axes.linewidth": 5, })
plt.figure(figsize=(13, 8))
ax = sns.histplot(data=dados_vendas, x="Valor_M", kde=True)
ax.set_title("Quntidade X Valor dos Imóveis")
ax.set_xlabel("Valor em Milhões")
ax.set_ylabel("Quantidade de Imóveis")
ax.legend(['Densidade de Probabilidade (KDE)'], prop={'size': 20})
plt.xlim((0, 12))
# Out:
# (0.0, 12.0)

# %% [markdown]
# ### Desafio 3

# %%
dados_vendas.groupby("Bairro").mean()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas      Valor  Valor_M
# Bairro
# Aclimação            246.16     3.27       3.04   2.91 1763200.01     1.76
# Alto da Boa Vista    418.88     4.12       5.12   4.62 2391250.00     2.39
# Alto da Lapa         299.25     3.15       3.85   4.00 2083168.75     2.08
# Alto da Mooca        270.05     3.30       2.60   3.65 1184170.00     1.18
# Alto de Pinheiros    429.85     3.94       4.83   4.95 4782698.96     4.78
# ...                     ...      ...        ...    ...        ...      ...
# Vila Água Funda      152.20     2.60       2.20   2.60  652000.00     0.65
# Água Branca          173.58     3.08       3.25   2.25 1226500.00     1.23
# Água Fria            165.42     2.83       3.42   2.50  927083.33     0.93
# Água Funda           139.00     3.00       2.50   2.00  545000.00     0.55
# Água Rasa            186.17     2.67       2.00   3.67  716166.67     0.72
#
# [697 rows x 6 columns]

# %%
media_valores_bairro = dados_vendas.groupby(
    'Bairro').mean()['Valor']
media_metragem_bairro = dados_vendas.groupby('Bairro').mean()['Metragem']


valor_metragem = media_valores_bairro/media_metragem_bairro
valor_metragem
# Out:
# Bairro
# Aclimação            7162.69
# Alto da Boa Vista    5708.74
# Alto da Lapa         6961.30
# Alto da Mooca        4385.00
# Alto de Pinheiros   11126.34
#                       ...
# Vila Água Funda      4283.84
# Água Branca          7065.77
# Água Fria            5604.53
# Água Funda           3920.86
# Água Rasa            3846.91
# Length: 697, dtype: float64

# %%
valor_metragem_sample = pd.DataFrame(valor_metragem.sample(20)).rename(
    columns={0: "Valor"})
valor_metragem_sample.sort_values('Valor', inplace=True)
valor_metragem_sample.reset_index(inplace=True)
valor_metragem_sample
# Out:
#                   Bairro   Valor
# 0   Parque CíSão Pauloer 2500.00
# 1     Engenheiro Goulart 2565.79
# 2               Itaquera 2611.21
# 3      Vila São Domingos 3368.42
# 4            Vila Alpina 3436.89
# 5    Vila Santa Virginia 3533.60
# 6   Vila Nova Manchester 3542.67
# 7      Vila Bonilha Nova 3835.65
# 8        Jardim Botucatu 4035.71
# 9            Vila Duarte 4134.62
# 10     Capela do Socorro 4166.67
# 11             Liberdade 4335.33
# 12         Jardim Guarau 4400.00
# 13        Vila Carmosina 4444.44
# 14           Vila Suzana 4548.31
# 15      Vila Santa Clara 4841.27
# 16         Jardim Franca 5064.06
# 17        Jardim Everest 7440.87
# 18           Sumarezinho 8164.64
# 19            Guaianases 8333.33

# %%
xMax = 13000
fig, ax = plt.subplots(figsize=(16, 10), dpi=300)
ax.hlines(y=valor_metragem_sample.index, xmin=0, xmax=xMax, color='gray',
          alpha=0.7, linewidth=1, linestyles='dashdot')
ax.scatter(y=valor_metragem_sample.index, x=valor_metragem_sample.Valor,
           s=75, color='firebrick', alpha=0.7)

ax.set_title('Preço por Metragem', fontdict={'size': 22})
ax.set_xlabel('Reais por metro quadrado')
ax.set_yticks(valor_metragem_sample.index)
ax.set_yticklabels(valor_metragem_sample.Bairro.str.title(), fontdict={
                   'horizontalalignment': 'right'})
ax.set_xlim(1500, xMax)
ax.margins(0.05)
plt.show()

# %% [markdown]
# ### desafio 4

# %%
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas       Valor  Valor_M
# count   9156.00  9156.00    9156.00 9156.00     9156.00  9156.00
# mean     434.42     3.45       3.80    3.96  3052202.96     3.05
# std     7856.42     1.05       1.97    2.60  3944208.19     3.94
# min       10.00     1.00       1.00    1.00    13000.00     0.01
# 25%      168.00     3.00       2.00    2.00   890000.00     0.89
# 50%      276.00     3.00       4.00    4.00  1800000.00     1.80
# 75%      450.00     4.00       5.00    5.00  3500000.00     3.50
# max   750000.00    16.00      40.00   50.00 65000000.00    65.00

# %%
df_num = dados_vendas[['Metragem', 'Quartos', 'Banheiros', 'Vagas', 'Valor']]
print(df_num.corr())
plt.figure(figsize=(13, 8), dpi=300)
ax = sns.heatmap(df_num.corr())
ax.figure.suptitle("Correlação entre Variaveis")
# Out:
#            Metragem  Quartos  Banheiros  Vagas  Valor
# Metragem       1.00     0.03       0.05   0.03   0.03
# Quartos        0.03     1.00       0.52   0.39   0.33
# Banheiros      0.05     0.52       1.00   0.45   0.43
# Vagas          0.03     0.39       0.45   1.00   0.47
# Valor          0.03     0.33       0.43   0.47   1.00
# Text(0.5, 0.98, 'Correlação entre Variaveis')

# %% [markdown]
# ### desafio 5

# %%
plt.figure(figsize=(13, 8), dpi=300)
ax = sns.boxplot(dados_vendas['Valor_M'])
plt.xticks(fontsize=14)
plt.xlabel('Preço em Milhões', fontsize=14)
plt.title('Distribuição de Preços', fontsize=20)
# Out:
# C:\Users\gabre\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribuição de Preços')

# %%
plt.figure(figsize=(13, 8), dpi=300)
ax = sns.boxplot(dados_vendas['Metragem'])
plt.xticks(fontsize=14)
plt.xlabel('Metragem', fontsize=14)
plt.title('Distribuição de Metragens', fontsize=20)
# Out:
# C:\Users\gabre\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribuição de Metragens')

# %%
plt.figure(figsize=(13, 8), dpi=300)
ax = sns.boxplot(dados_vendas['Metragem'])
plt.xticks(fontsize=14)
plt.xlabel('Metragem', fontsize=14)
plt.title('Distribuição de Metragens', fontsize=20)
ax.set_xlim(-5, 3000)
# Out:
# C:\Users\gabre\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (-5.0, 3000.0)

# %%
plt.figure(figsize=(13, 8), dpi=300)
ax = sns.boxplot(dados_vendas['Quartos'])
plt.xticks(fontsize=14)
plt.xlabel('Numero de Quartos', fontsize=14)
plt.title('Distribuição de Quartos', fontsize=20)
# Out:
# C:\Users\gabre\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribuição de Quartos')

# %%
plt.figure(figsize=(13, 8), dpi=300)
ax = sns.boxplot(dados_vendas['Banheiros'])
plt.xticks(fontsize=14)
plt.xlabel('Numero de Banheiros', fontsize=14)
plt.title('Distribuição de Banheiros', fontsize=20)
# Out:
# C:\Users\gabre\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribuição de Banheiros')
