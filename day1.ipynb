# %% [markdown]
# # Dia 1 da semana de dados da Alura

# %% [markdown]
# ## Aula

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")
sns.set_context("poster", font_scale = 1, rc={"grid.linewidth": 5})
sns.set_palette("colorblind")

dados = pd.read_csv('dados_imoveis.csv')
dados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
dados.sample(10)
# Out:
#                                          Rua                Bairro     Cidade  \
# 3059            Rua Engenheiro Janot Pacheco       Vila Progredior  São Paulo
# 6900                        Avenida Portugal     Brooklin Paulista  São Paulo
# 6325                            Rua Iguatemi            Itaim Bibi  São Paulo
# 1787        Rua Marechal Renato Paquet, 463       Jardim Marajoara  São Paulo
# 3472                      Rua Heitor Peixoto               Cambuci  São Paulo
# 958   Rua Professor Miguel Maurício da Rocha     Brooklin Paulista  São Paulo
# 87                                       NaN     Planalto Paulista  São Paulo
# 518                  Rua Eunice Weaver, 235   Jardim Anália Franco  São Paulo
# 3462                                     NaN          Jardim Viana  São Paulo
# 5055                                     NaN             Vila Nair  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados.query('Bairro == "Vila Mariana"').Metragem.mean()
# Out:
# 233.6195652173913

# %%
n_imoveis_bairro = dados['Bairro'].value_counts()
n_imoveis_bairro.head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média de metragem por bairro
#
# 2 - 2 formas de selecionar por bairro
#
# 3 - Explorar alguns graficos na documentação e aplicar nas demais linhas do DF, tentar colocar alguma conclusão
#
# 4 - Pegar outras estatisticas dos dados, como média, mediana, min, e max e derivar conclusões
#
# 5 - Descobrir quais bairros não tem nome da rua

# %% [markdown]
# ## Desafios

# %% [markdown]
# ### 1 - Metragem por bairros

# %%
m_bairro = dados.groupby('Bairro').Metragem.mean()
m_bairro
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %%
m_bairro.sort_values(ascending=False).head(10)
# Out:
# Bairro
# Sítio Represa                 37000.000000
# Vila Castelo                   2850.000000
# Jardim Guedala                 2486.640199
# Jardim das Camélias            1700.000000
# Chácara Flora                  1260.727273
# Jardim Sílvia (Zona Oeste)     1189.258065
# Retiro Morumbi                 1084.045455
# Vila Aurora (Zona Norte)       1082.500000
# Paineiras do Morumbi            757.266667
# Vila Ivone                      722.500000
# Name: Metragem, dtype: float64

# %%
m_bairro.sort_values(ascending=False).head(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='Bairro'>

# %%
dados.query('Bairro == "Sítio Represa"')
# Out:
#                          Rua         Bairro     Cidade  Metragem  Quartos  \
# 6600  Rua Benedito Felizardo  Sítio Represa  São Paulo     37000        4
#
#       Banheiros  Vagas         Valor
# 6600          2      4  R$ 2.900.000

# %%
m_bairro.sort_values(ascending=False).sample(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='Bairro'>

# %% [markdown]
# 2 - 2 formas de selecionar por bairro

# %%
dados[dados["Bairro"] == "Vila Mariana"]
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
dados.query('Bairro == "Vila Mariana"')
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
dados.set_index('Bairro', append=True, drop=False).xs("Vila Mariana", level=1)
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %% [markdown]
# 3 - Explorar alguns graficos na documentação e aplicar nas demais linhas do DF, tentar colocar alguma conclusão

# %%
df_num = dados[['Metragem', 'Quartos', 'Banheiros', 'Vagas']]
df_cat = dados[['Rua','Bairro','Cidade','Valor']]

# %%
sns.set_context('notebook', font_scale=1, rc={"grid.linewidth": 1.3})
for i in df_num.columns:
    plt.hist(df_num[i])
    plt.title(i)
    plt.show()

# %%
sns.set_context('poster')
print(df_num.corr())
sns.heatmap(df_num.corr())
# Out:
#            Metragem   Quartos  Banheiros     Vagas
# Metragem   1.000000  0.031716   0.045113  0.028589
# Quartos    0.031716  1.000000   0.514286  0.380124
# Banheiros  0.045113  0.514286   1.000000  0.451626
# Vagas      0.028589  0.380124   0.451626  1.000000
# <AxesSubplot:>

# %% [markdown]
# 4 - Pegar outras estatisticas dos dados, como média, mediana, min, e max e derivar conclusões

# %%
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %%
dados.query('Metragem == 750000')
# Out:
#                               Rua          Bairro     Cidade  Metragem  \
# 9845  Avenida George Saville Dodd  Jardim Guedala  São Paulo    750000
#
#       Quartos  Banheiros  Vagas         Valor
# 9845        5          9      6  R$ 7.000.000

# %% [markdown]
# 5 - Descobrir quais bairros não tem nome da rua

# %%
dados[dados['Rua'].isnull()]
# Out:
#       Rua                            Bairro     Cidade  Metragem  Quartos  \
# 3     NaN                    Jardim Morumbi  São Paulo       310        3
# 11    NaN                  Jardim Luzitânia  São Paulo       436        4
# 31    NaN                    Parque da Lapa  São Paulo       220        4
# 56    NaN  Chácara Santo Antônio (Zona Sul)  São Paulo       190        2
# 57    NaN                    Jardim Guedala  São Paulo       650        4
# ...   ...                               ...        ...       ...      ...
# 9963  NaN                 Jardim Petrópolis  São Paulo       423        5
# 9989  NaN              Parque Alves de Lima  São Paulo       127        2
# 9991  NaN                      Vila Formosa  São Paulo       145        3
# 9995  NaN                     Jardim Leonor  São Paulo      1350        5
# 9999  NaN                 Jardim Petrópolis  São Paulo       423        5
#
#       Banheiros  Vagas         Valor
# 3             2      4    R$ 685.000
# ...

# %%
dados.query('Rua.isnull()')['Bairro'].value_counts()
# Out:
# Jardim Guedala                      190
# Alto de Pinheiros                   169
# Jardim Paulista                     138
# Jardim Europa                       128
# Jardim Leonor                       118
#                                    ...
# Jardim do Colégio (Zona Norte)        1
# Alto da Boa Vista                     1
# Jardim Aeroporto                      1
# Conjunto Residencial Vista Verde      1
# Jardim Santo Elias                    1
# Name: Bairro, Length: 394, dtype: int64

# %%
dados.query('Rua.isnull()')['Bairro'].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>
